# %% [markdown]
# # Working with Sequence Data using `R` and `Bioconductor`

# %% [markdown]
# `Bioconductor` is a collection ([> 2000](https://www.bioconductor.org/packages/release/BiocViews.html#___Software)) of `R` packages focused on biological data analysis.
#
# **Packages we will use today**
#
#
# - [`Biostrings`](https://bioconductor.org/packages/release/bioc/html/Biostrings.html) for working with DNA, RNA, and protein sequences
# - [`rtracklayer`](https://bioconductor.org/packages/release/bioc/html/rtracklayer.html) for working with sequence annotation files (GFF, BED)
# - [`plyranges`](https://bioconductor.org/packages/release/bioc/html/plyranges.html) for a `tidyverse`-like interface to Bioconductor data objects.
# - [`BSgenome.Hsapiens.UCSC.hg38`](https://bioconductor.org/packages/release/data/annotation/html/BSgenome.Hsapiens.UCSC.hg38.html) for human genome sequence data
# - [`GenomicFeatures`](https://bioconductor.org/packages/release/bioc/html/GenomicFeatures.html) for working with transcript annotations
# - [`ggbio`](https://www.bioconductor.org/packages/release/bioc/html/ggbio.html) GGplot2-like plotting interface for biological data

# %% [markdown]
# ## Package Installation
#
# For installing `Bioconductor` packages using `conda`, I search for the package name + `conda` for finding the relevant `conda` package name and repository.
#
# For example, the first link [here](https://www.google.com/search?q=biostrings+conda) is the `conda` package for `biostrings` which I would install as:
#
# ```bash
# conda activate tidy # tidy is name of R environment
# conda install -c bioconda bioconductor-biostrings
# ```

# %% [markdown]
# ## How to learn further
#
# - `Documentation` section of package homepage on `Bioconductor` website, eg. [`plyranges`](https://bioconductor.org/packages/release/bioc/html/plyranges.html)
# - Bioconductor workshops, eg. [`plyranges`](https://bioconductor.github.io/BiocWorkshops/fluent-genomic-data-analysis-with-plyranges.htmlhttps://bioconductor.org/workshops/plyranges/)
# - [Q & A](https://support.bioconductor.org/) section of `Bioconductor` website

# %% [markdown]
# ## Load packages
#
# Note: Many functions are named the same across different packages. For example, `select`, `n`, `rename` etc. This can lead to confusing errors.
#
# If you are getting errors when you use a function, try loading the packages in a different order or specify the package name explicitly. For example, use `dplyr::rename()`, `plyranges::select()`, etc.

# %%
suppressPackageStartupMessages({
  library(Biostrings)
  library(rtracklayer)
  library(plyranges)
  library(tidyverse)
})

# %% [markdown]
# ## Working with sequence data using `Biostrings`

# %%
seqs <- readDNAStringSet("data/tumor_suppressors.fasta") %>%
  print()
# Out:
# DNAStringSet object of length 5:
#     width seq                                               names
# [1]  1182 ATGGAGGAGCCGCAGTCAGATCC...CAGAAGGGCCTGACTCAGACTGA TP53
# [2]  1212 ATGACAGCCATCATCAAAGAGAT...ATACACAAATTACAAAAGTCTGA PTEN
# [3]  5655 ATGGATTTATCTGCTCTTCGCGT...AGATCCCCCACAGCCACTACTGA BRCA1
# [4] 10257 ATGCCTATTGGATCCAAAGAGAG...TTACAACTAAAAAATATATCTAA BRCA2
# [5]  2787 ATGCCGCCCAAAACCCCCCGAAA...CCTCAAACAAGGAAGAGAAATGA RB1

# %% [markdown]
# Reverse complement

# %%
seqs %>%
  reverseComplement()
# Out:
# DNAStringSet object of length 5:
#     width seq                                               names
# [1]  1182 TCAGTCTGAGTCAGGCCCTTCTG...GGATCTGACTGCGGCTCCTCCAT TP53
# [2]  1212 TCAGACTTTTGTAATTTGTGTAT...ATCTCTTTGATGATGGCTGTCAT PTEN
# [3]  5655 TCAGTAGTGGCTGTGGGGGATCT...ACGCGAAGAGCAGATAAATCCAT BRCA1
# [4] 10257 TTAGATATATTTTTTAGTTGTAA...CTCTCTTTGGATCCAATAGGCAT BRCA2
# [5]  2787 TCATTTCTCTTCCTTGTTTGAGG...TTTCGGGGGGTTTTGGGCGGCAT RB1

# %% [markdown]
# Translate

# %%
seqs %>%
  translate()
# Out:
# AAStringSet object of length 5:
#     width seq                                               names
# [1]   394 MEEPQSDPSVEPPLSQETFSDLW...KKGQSTSRHKKLMFKTEGPDSD* TP53
# [2]   404 MTAIIKEIVSRNKRRYQEDGFDL...TTDSDPENEPFDEDQHTQITKV* PTEN
# [3]  1885 MDLSALRVEEVQNVINAMQKILE...VALYQCQELDTYLIPQIPHSHY* BRCA1
# [4]  3419 MPIGSKERPTFFEIFKTRCNKAD...SQASTEECEKNKQDTITTKKYI* BRCA2
# [5]   929 MPPKTPRKTAATAAAAAAEPPAP...TRTRMQKQKMNDSMDTSNKEEK* RB1

# %% [markdown]
# Get a sub-sequence

# %%
seqs %>%
  subseq(1,10)
# Out:
# DNAStringSet object of length 5:
#     width seq                                               names
# [1]    10 ATGGAGGAGC                                        TP53
# [2]    10 ATGACAGCCA                                        PTEN
# [3]    10 ATGGATTTAT                                        BRCA1
# [4]    10 ATGCCTATTG                                        BRCA2
# [5]    10 ATGCCGCCCA                                        RB1

# %% [markdown]
# Calculate codon frequencies

# %%
seqs %>%
  oligonucleotideFrequency(width = 3, step = 3) %>%
  as_tibble()
# Out:
#   AAA AAC AAG AAT ACA ACC ACG ACT AGA AGC ⋯ TCG TCT TGA TGC TGG TGT TTA TTC TTG
# 1   7 10  13    4  7   9  2     4  3   8  ⋯ 0     7 1    6   4   4   0   7   6
# 2  19  7  15   16  9   5  0     7  8   4  ⋯ 0     4 1    4   2   6   7  10   3
# 3  80 40  58   83 38  24  7    42 35  44  ⋯ 2    66 1   12  10  32  34  16  34
# 4 228 63  94  167 80  29  8   103 65  33  ⋯ 4   121 0   15  20  61  84  26  51
# 5  60 14  16   31 23  12  2    18 15   9  ⋯ 3    22 1    3   7  12  19  13  17
#   TTT
# 1   4
# 2  15
# 3  34
# 4 110
# 5  26

# %% [markdown]
# You can also read `fastq` files but not recommended for large files
#
# See `ShortRead` package for working with large number of sequence reads

# %%
readDNAStringSet("../lecture08/barcodes_R1.fastq", format = "fastq") %>%
  # reverseComplement() %>%
  # # convert to a tibble
  # as.data.frame() %>%
  # rownames_to_column() %>%
  # setNames(c("name", "seq")) %>%
  # # ----------------
  # mutate(is_HA = str_detect(seq, "CCGGATTTGCATATAATGATGCACCAT")) %>%
  # mutate(is_NA = str_detect(seq, "CACGATAGATAAATAATAGTGCACCAT")) %>%
  # mutate(barcode = substr(seq, nchar(seq) - 16, nchar(seq))) %>%
  # # select(-seq)
  # group_by(is_HA, is_NA, barcode) %>%
  # summarize(n_HA = sum(is_HA), n_NA = sum(is_NA)) %>%
  # filter(n_NA > 0) %>%
  # arrange(-n_NA) %>%
  print()
# Out:
# DNAStringSet object of length 10000:
#         width seq                                           names
#     [1]   250 GCTTAAGTTATTTAGTGCGGC...TTATTGACACGGAATAGCAGA HISEQ:621:HMJGNBC...
#     [2]   250 CTTCCTGGTCACGGTTGCGGC...CCCTAATGACAGAGTGTACGA HISEQ:621:HMJGNBC...
#     [3]   250 CACGGCTATTACCCCGCGGCC...CCCTTCTACTATACACTACGA HISEQ:621:HMJGNBC...
#     [4]   250 TCAGCGATGAATGTGGGCGGC...CACCAACTACCATTCATCTGA HISEQ:621:HMJGNBC...
#     [5]   250 ATATGGGAGACGATAAGCGGC...CCCAGAACACAGTCTTTACTC HISEQ:621:HMJGNBC...
#     ...   ... ...
#  [9996]   250 GCCGTATGGCTGGTGGGCGGC...CTCAGAAGACACCTACAACCC HISEQ:621:HMJGNBC...
#  [9997]   250 GGACAGCAGGGAGCGGGCGGC...TTGAGGTTACAGATTATACGC HISEQ:621:HMJGNBC...
#  [9998]   250 TTTATATGAGTTTCGTGCGGC...TGCGACACTCCACTACTCCCG HISEQ:621:HMJGNBC...
#  [9999]   250 GGAGTTTATAACATGCGCGGC...TCCTGAACACCGTTCTTACGA HISEQ:621:HMJGNBC...
# [10000]   250 CGTAGGATTGAATTAGGCGGC...ATCTGCAGACAAATAATATAA HISEQ:621:HMJGNBC...

# %% [markdown]
# # How do we get sequence data for a specific gene or transcript?

# %%
genome <- BSgenome.Hsapiens.UCSC.hg38::BSgenome.Hsapiens.UCSC.hg38

# %% [markdown]
# Chromosome names

# %%
seqnames(genome)
# Out:
#   [1] "chr1"                    "chr2"
#   [3] "chr3"                    "chr4"
#   [5] "chr5"                    "chr6"
#   [7] "chr7"                    "chr8"
#   [9] "chr9"                    "chr10"
#  [11] "chr11"                   "chr12"
#  [13] "chr13"                   "chr14"
#  [15] "chr15"                   "chr16"
#  [17] "chr17"                   "chr18"
#  [19] "chr19"                   "chr20"
#  [21] "chr21"                   "chr22"
#  [23] "chrX"                    "chrY"
#  [25] "chrM"                    "chr1_GL383518v1_alt"
#  [27] "chr1_GL383519v1_alt"     "chr1_GL383520v2_alt"
#  [29] "chr1_KI270759v1_alt"     "chr1_KI270760v1_alt"
#  [31] "chr1_KI270761v1_alt"     "chr1_KI270762v1_alt"
#  [33] "chr1_KI270763v1_alt"     "chr1_KI270764v1_alt"
#  [35] "chr1_KI270765v1_alt"     "chr1_KI270766v1_alt"
#  [37] "chr1_KI270892v1_alt"     "chr2_GL383521v1_alt"
#  [39] "chr2_GL383522v1_alt"     "chr2_GL582966v2_alt"
#  [41] "chr2_KI270767v1_alt"     "chr2_KI270768v1_alt"
#  [43] "chr2_KI270769v1_alt"     "chr2_KI270770v1_alt"
#  [45] "chr2_KI270771v1_alt"     "chr2_KI270772v1_alt"
#  [47] "chr2_KI270773v1_alt"     "chr2_KI270774v1_alt"
#  [49] "chr2_KI270775v1_alt"     "chr2_KI270776v1_alt"
#  [51] "chr2_KI270893v1_alt"     "chr2_KI270894v1_alt"
#  [53] "chr3_GL383526v1_alt"     "chr3_JH636055v2_alt"
#  [55] "chr3_KI270777v1_alt"     "chr3_KI270778v1_alt"
#  [57] "chr3_KI270779v1_alt"     "chr3_KI270780v1_alt"
#  [59] "chr3_KI270781v1_alt"     "chr3_KI270782v1_alt"
#  [61] "chr3_KI270783v1_alt"     "chr3_KI270784v1_alt"
#  [63] "chr3_KI270895v1_alt"     "chr3_KI270924v1_alt"
#  [65] "chr3_KI270934v1_alt"     "chr3_KI270935v1_alt"
#  [67] "chr3_KI270936v1_alt"     "chr3_KI270937v1_alt"
#  [69] "chr4_GL000257v2_alt"     "chr4_GL383527v1_alt"
#  [71] "chr4_GL383528v1_alt"     "chr4_KI270785v1_alt"
#  [73] "chr4_KI270786v1_alt"     "chr4_KI270787v1_alt"
#  [75] "chr4_KI270788v1_alt"     "chr4_KI270789v1_alt"
#  [77] "chr4_KI270790v1_alt"     "chr4_KI270896v1_alt"
#  [79] "chr4_KI270925v1_alt"     "chr5_GL339449v2_alt"
#  [81] "chr5_GL383530v1_alt"     "chr5_GL383531v1_alt"
#  [83] "chr5_GL383532v1_alt"     "chr5_GL949742v1_alt"
#  [85] "chr5_KI270791v1_alt"     "chr5_KI270792v1_alt"
#  [87] "chr5_KI270793v1_alt"     "chr5_KI270794v1_alt"
#  [89] "chr5_KI270795v1_alt"     "chr5_KI270796v1_alt"
#  [91] "chr5_KI270897v1_alt"     "chr5_KI270898v1_alt"
#  [93] "chr6_GL000250v2_alt"     "chr6_GL000251v2_alt"
#  [95] "chr6_GL000252v2_alt"     "chr6_GL000253v2_alt"
#  [97] "chr6_GL000254v2_alt"     "chr6_GL000255v2_alt"
#  [99] "chr6_GL000256v2_alt"     "chr6_GL383533v1_alt"
# [101] "chr6_KB021644v2_alt"     "chr6_KI270758v1_alt"
# [103] "chr6_KI270797v1_alt"     "chr6_KI270798v1_alt"
# [105] "chr6_KI270799v1_alt"     "chr6_KI270800v1_alt"
# [107] "chr6_KI270801v1_alt"     "chr6_KI270802v1_alt"
# [109] "chr7_GL383534v2_alt"     "chr7_KI270803v1_alt"
# [111] "chr7_KI270804v1_alt"     "chr7_KI270805v1_alt"
# [113] "chr7_KI270806v1_alt"     "chr7_KI270807v1_alt"
# [115] "chr7_KI270808v1_alt"     "chr7_KI270809v1_alt"
# [117] "chr7_KI270899v1_alt"     "chr8_KI270810v1_alt"
# [119] "chr8_KI270811v1_alt"     "chr8_KI270812v1_alt"
# [121] "chr8_KI270813v1_alt"     "chr8_KI270814v1_alt"
# [123] "chr8_KI270815v1_alt"     "chr8_KI270816v1_alt"
# [125] "chr8_KI270817v1_alt"     "chr8_KI270818v1_alt"
# [127] "chr8_KI270819v1_alt"     "chr8_KI270820v1_alt"
# [129] "chr8_KI270821v1_alt"     "chr8_KI270822v1_alt"
# [131] "chr8_KI270900v1_alt"     "chr8_KI270901v1_alt"
# [133] "chr8_KI270926v1_alt"     "chr9_GL383539v1_alt"
# [135] "chr9_GL383540v1_alt"     "chr9_GL383541v1_alt"
# [137] "chr9_GL383542v1_alt"     "chr9_KI270823v1_alt"
# [139] "chr10_GL383545v1_alt"    "chr10_GL383546v1_alt"
# [141] "chr10_KI270824v1_alt"    "chr10_KI270825v1_alt"
# [143] "chr11_GL383547v1_alt"    "chr11_JH159136v1_alt"
# [145] "chr11_JH159137v1_alt"    "chr11_KI270826v1_alt"
# [147] "chr11_KI270827v1_alt"    "chr11_KI270829v1_alt"
# [149] "chr11_KI270830v1_alt"    "chr11_KI270831v1_alt"
# [151] "chr11_KI270832v1_alt"    "chr11_KI270902v1_alt"
# [153] "chr11_KI270903v1_alt"    "chr11_KI270927v1_alt"
# [155] "chr12_GL383549v1_alt"    "chr12_GL383550v2_alt"
# [157] "chr12_GL383551v1_alt"    "chr12_GL383552v1_alt"
# [159] "chr12_GL383553v2_alt"    "chr12_GL877875v1_alt"
# [161] "chr12_GL877876v1_alt"    "chr12_KI270833v1_alt"
# [163] "chr12_KI270834v1_alt"    "chr12_KI270835v1_alt"
# [165] "chr12_KI270836v1_alt"    "chr12_KI270837v1_alt"
# [167] "chr12_KI270904v1_alt"    "chr13_KI270838v1_alt"
# [169] "chr13_KI270839v1_alt"    "chr13_KI270840v1_alt"
# [171] "chr13_KI270841v1_alt"    "chr13_KI270842v1_alt"
# [173] "chr13_KI270843v1_alt"    "chr14_KI270844v1_alt"
# [175] "chr14_KI270845v1_alt"    "chr14_KI270846v1_alt"
# [177] "chr14_KI270847v1_alt"    "chr15_GL383554v1_alt"
# [179] "chr15_GL383555v2_alt"    "chr15_KI270848v1_alt"
# [181] "chr15_KI270849v1_alt"    "chr15_KI270850v1_alt"
# [183] "chr15_KI270851v1_alt"    "chr15_KI270852v1_alt"
# [185] "chr15_KI270905v1_alt"    "chr15_KI270906v1_alt"
# [187] "chr16_GL383556v1_alt"    "chr16_GL383557v1_alt"
# [189] "chr16_KI270853v1_alt"    "chr16_KI270854v1_alt"
# [191] "chr16_KI270855v1_alt"    "chr16_KI270856v1_alt"
# [193] "chr17_GL000258v2_alt"    "chr17_GL383563v3_alt"
# [195] "chr17_GL383564v2_alt"    "chr17_GL383565v1_alt"
# [197] "chr17_GL383566v1_alt"    "chr17_JH159146v1_alt"
# [199] "chr17_JH159147v1_alt"    "chr17_JH159148v1_alt"
# [201] "chr17_KI270857v1_alt"    "chr17_KI270858v1_alt"
# [203] "chr17_KI270859v1_alt"    "chr17_KI270860v1_alt"
# [205] "chr17_KI270861v1_alt"    "chr17_KI270862v1_alt"
# [207] "chr17_KI270907v1_alt"    "chr17_KI270908v1_alt"
# [209] "chr17_KI270909v1_alt"    "chr17_KI270910v1_alt"
# [211] "chr18_GL383567v1_alt"    "chr18_GL383568v1_alt"
# [213] "chr18_GL383569v1_alt"    "chr18_GL383570v1_alt"
# [215] "chr18_GL383571v1_alt"    "chr18_GL383572v1_alt"
# [217] "chr18_KI270863v1_alt"    "chr18_KI270864v1_alt"
# [219] "chr18_KI270911v1_alt"    "chr18_KI270912v1_alt"
# [221] "chr19_GL000209v2_alt"    "chr19_GL383573v1_alt"
# [223] "chr19_GL383574v1_alt"    "chr19_GL383575v2_alt"
# [225] "chr19_GL383576v1_alt"    "chr19_GL949746v1_alt"
# [227] "chr19_GL949747v2_alt"    "chr19_GL949748v2_alt"
# [229] "chr19_GL949749v2_alt"    "chr19_GL949750v2_alt"
# [231] "chr19_GL949751v2_alt"    "chr19_GL949752v1_alt"
# [233] "chr19_GL949753v2_alt"    "chr19_KI270865v1_alt"
# [235] "chr19_KI270866v1_alt"    "chr19_KI270867v1_alt"
# [237] "chr19_KI270868v1_alt"    "chr19_KI270882v1_alt"
# [239] "chr19_KI270883v1_alt"    "chr19_KI270884v1_alt"
# [241] "chr19_KI270885v1_alt"    "chr19_KI270886v1_alt"
# [243] "chr19_KI270887v1_alt"    "chr19_KI270888v1_alt"
# [245] "chr19_KI270889v1_alt"    "chr19_KI270890v1_alt"
# [247] "chr19_KI270891v1_alt"    "chr19_KI270914v1_alt"
# [249] "chr19_KI270915v1_alt"    "chr19_KI270916v1_alt"
# [251] "chr19_KI270917v1_alt"    "chr19_KI270918v1_alt"
# [253] "chr19_KI270919v1_alt"    "chr19_KI270920v1_alt"
# [255] "chr19_KI270921v1_alt"    "chr19_KI270922v1_alt"
# [257] "chr19_KI270923v1_alt"    "chr19_KI270929v1_alt"
# [259] "chr19_KI270930v1_alt"    "chr19_KI270931v1_alt"
# [261] "chr19_KI270932v1_alt"    "chr19_KI270933v1_alt"
# [263] "chr19_KI270938v1_alt"    "chr20_GL383577v2_alt"
# [265] "chr20_KI270869v1_alt"    "chr20_KI270870v1_alt"
# [267] "chr20_KI270871v1_alt"    "chr21_GL383578v2_alt"
# [269] "chr21_GL383579v2_alt"    "chr21_GL383580v2_alt"
# [271] "chr21_GL383581v2_alt"    "chr21_KI270872v1_alt"
# [273] "chr21_KI270873v1_alt"    "chr21_KI270874v1_alt"
# [275] "chr22_GL383582v2_alt"    "chr22_GL383583v2_alt"
# [277] "chr22_KB663609v1_alt"    "chr22_KI270875v1_alt"
# [279] "chr22_KI270876v1_alt"    "chr22_KI270877v1_alt"
# [281] "chr22_KI270878v1_alt"    "chr22_KI270879v1_alt"
# [283] "chr22_KI270928v1_alt"    "chrX_KI270880v1_alt"
# [285] "chrX_KI270881v1_alt"     "chrX_KI270913v1_alt"
# [287] "chr1_KI270706v1_random"  "chr1_KI270707v1_random"
# [289] "chr1_KI270708v1_random"  "chr1_KI270709v1_random"
# [291] "chr1_KI270710v1_random"  "chr1_KI270711v1_random"
# [293] "chr1_KI270712v1_random"  "chr1_KI270713v1_random"
# [295] "chr1_KI270714v1_random"  "chr2_KI270715v1_random"
# [297] "chr2_KI270716v1_random"  "chr3_GL000221v1_random"
# [299] "chr4_GL000008v2_random"  "chr5_GL000208v1_random"
# [301] "chr9_KI270717v1_random"  "chr9_KI270718v1_random"
# [303] "chr9_KI270719v1_random"  "chr9_KI270720v1_random"
# [305] "chr11_KI270721v1_random" "chr14_GL000009v2_random"
# [307] "chr14_GL000194v1_random" "chr14_GL000225v1_random"
# [309] "chr14_KI270722v1_random" "chr14_KI270723v1_random"
# [311] "chr14_KI270724v1_random" "chr14_KI270725v1_random"
# [313] "chr14_KI270726v1_random" "chr15_KI270727v1_random"
# [315] "chr16_KI270728v1_random" "chr17_GL000205v2_random"
# [317] "chr17_KI270729v1_random" "chr17_KI270730v1_random"
# [319] "chr22_KI270731v1_random" "chr22_KI270732v1_random"
# [321] "chr22_KI270733v1_random" "chr22_KI270734v1_random"
# [323] "chr22_KI270735v1_random" "chr22_KI270736v1_random"
# [325] "chr22_KI270737v1_random" "chr22_KI270738v1_random"
# [327] "chr22_KI270739v1_random" "chrY_KI270740v1_random"
# [329] "chrUn_GL000195v1"        "chrUn_GL000213v1"
# [331] "chrUn_GL000214v1"        "chrUn_GL000216v2"
# [333] "chrUn_GL000218v1"        "chrUn_GL000219v1"
# [335] "chrUn_GL000220v1"        "chrUn_GL000224v1"
# [337] "chrUn_GL000226v1"        "chrUn_KI270302v1"
# [339] "chrUn_KI270303v1"        "chrUn_KI270304v1"
# [341] "chrUn_KI270305v1"        "chrUn_KI270310v1"
# [343] "chrUn_KI270311v1"        "chrUn_KI270312v1"
# [345] "chrUn_KI270315v1"        "chrUn_KI270316v1"
# [347] "chrUn_KI270317v1"        "chrUn_KI270320v1"
# [349] "chrUn_KI270322v1"        "chrUn_KI270329v1"
# [351] "chrUn_KI270330v1"        "chrUn_KI270333v1"
# [353] "chrUn_KI270334v1"        "chrUn_KI270335v1"
# [355] "chrUn_KI270336v1"        "chrUn_KI270337v1"
# [357] "chrUn_KI270338v1"        "chrUn_KI270340v1"
# [359] "chrUn_KI270362v1"        "chrUn_KI270363v1"
# [361] "chrUn_KI270364v1"        "chrUn_KI270366v1"
# [363] "chrUn_KI270371v1"        "chrUn_KI270372v1"
# [365] "chrUn_KI270373v1"        "chrUn_KI270374v1"
# [367] "chrUn_KI270375v1"        "chrUn_KI270376v1"
# [369] "chrUn_KI270378v1"        "chrUn_KI270379v1"
# [371] "chrUn_KI270381v1"        "chrUn_KI270382v1"
# [373] "chrUn_KI270383v1"        "chrUn_KI270384v1"
# [375] "chrUn_KI270385v1"        "chrUn_KI270386v1"
# [377] "chrUn_KI270387v1"        "chrUn_KI270388v1"
# [379] "chrUn_KI270389v1"        "chrUn_KI270390v1"
# [381] "chrUn_KI270391v1"        "chrUn_KI270392v1"
# [383] "chrUn_KI270393v1"        "chrUn_KI270394v1"
# [385] "chrUn_KI270395v1"        "chrUn_KI270396v1"
# [387] "chrUn_KI270411v1"        "chrUn_KI270412v1"
# [389] "chrUn_KI270414v1"        "chrUn_KI270417v1"
# [391] "chrUn_KI270418v1"        "chrUn_KI270419v1"
# [393] "chrUn_KI270420v1"        "chrUn_KI270422v1"
# [395] "chrUn_KI270423v1"        "chrUn_KI270424v1"
# [397] "chrUn_KI270425v1"        "chrUn_KI270429v1"
# [399] "chrUn_KI270435v1"        "chrUn_KI270438v1"
# [401] "chrUn_KI270442v1"        "chrUn_KI270448v1"
# [403] "chrUn_KI270465v1"        "chrUn_KI270466v1"
# [405] "chrUn_KI270467v1"        "chrUn_KI270468v1"
# [407] "chrUn_KI270507v1"        "chrUn_KI270508v1"
# [409] "chrUn_KI270509v1"        "chrUn_KI270510v1"
# [411] "chrUn_KI270511v1"        "chrUn_KI270512v1"
# [413] "chrUn_KI270515v1"        "chrUn_KI270516v1"
# [415] "chrUn_KI270517v1"        "chrUn_KI270518v1"
# [417] "chrUn_KI270519v1"        "chrUn_KI270521v1"
# [419] "chrUn_KI270522v1"        "chrUn_KI270528v1"
# [421] "chrUn_KI270529v1"        "chrUn_KI270530v1"
# [423] "chrUn_KI270538v1"        "chrUn_KI270539v1"
# [425] "chrUn_KI270544v1"        "chrUn_KI270548v1"
# [427] "chrUn_KI270579v1"        "chrUn_KI270580v1"
# [429] "chrUn_KI270581v1"        "chrUn_KI270582v1"
# [431] "chrUn_KI270583v1"        "chrUn_KI270584v1"
# [433] "chrUn_KI270587v1"        "chrUn_KI270588v1"
# [435] "chrUn_KI270589v1"        "chrUn_KI270590v1"
# [437] "chrUn_KI270591v1"        "chrUn_KI270593v1"
# [439] "chrUn_KI270741v1"        "chrUn_KI270742v1"
# [441] "chrUn_KI270743v1"        "chrUn_KI270744v1"
# [443] "chrUn_KI270745v1"        "chrUn_KI270746v1"
# [445] "chrUn_KI270747v1"        "chrUn_KI270748v1"
# [447] "chrUn_KI270749v1"        "chrUn_KI270750v1"
# [449] "chrUn_KI270751v1"        "chrUn_KI270752v1"
# [451] "chrUn_KI270753v1"        "chrUn_KI270754v1"
# [453] "chrUn_KI270755v1"        "chrUn_KI270756v1"
# [455] "chrUn_KI270757v1"        "chr1_KN196472v1_fix"
# [457] "chr1_KN196473v1_fix"     "chr1_KN196474v1_fix"
# [459] "chr1_KN538360v1_fix"     "chr1_KN538361v1_fix"
# [461] "chr1_KQ031383v1_fix"     "chr1_KZ208906v1_fix"
# [463] "chr1_KZ559100v1_fix"     "chr2_KN538362v1_fix"
# [465] "chr2_KN538363v1_fix"     "chr2_KQ031384v1_fix"
# [467] "chr2_ML143341v1_fix"     "chr2_ML143342v1_fix"
# [469] "chr3_KN196475v1_fix"     "chr3_KN196476v1_fix"
# [471] "chr3_KN538364v1_fix"     "chr3_KQ031385v1_fix"
# [473] "chr3_KQ031386v1_fix"     "chr3_KV766192v1_fix"
# [475] "chr3_KZ559104v1_fix"     "chr4_KQ983257v1_fix"
# [477] "chr4_ML143344v1_fix"     "chr4_ML143345v1_fix"
# [479] "chr4_ML143346v1_fix"     "chr4_ML143347v1_fix"
# [481] "chr4_ML143348v1_fix"     "chr4_ML143349v1_fix"
# [483] "chr5_KV575244v1_fix"     "chr5_ML143350v1_fix"
# [485] "chr6_KN196478v1_fix"     "chr6_KQ031387v1_fix"
# [487] "chr6_KQ090016v1_fix"     "chr6_KV766194v1_fix"
# [489] "chr6_KZ208911v1_fix"     "chr6_ML143351v1_fix"
# [491] "chr7_KQ031388v1_fix"     "chr7_KV880764v1_fix"
# [493] "chr7_KV880765v1_fix"     "chr7_KZ208912v1_fix"
# [495] "chr7_ML143352v1_fix"     "chr8_KV880766v1_fix"
# [497] "chr8_KV880767v1_fix"     "chr8_KZ208914v1_fix"
# [499] "chr8_KZ208915v1_fix"     "chr9_KN196479v1_fix"
# [501] "chr9_ML143353v1_fix"     "chr10_KN196480v1_fix"
# [503] "chr10_KN538365v1_fix"    "chr10_KN538366v1_fix"
# [505] "chr10_KN538367v1_fix"    "chr10_KQ090021v1_fix"
# [507] "chr10_ML143354v1_fix"    "chr10_ML143355v1_fix"
# [509] "chr11_KN196481v1_fix"    "chr11_KQ090022v1_fix"
# [511] "chr11_KQ759759v1_fix"    "chr11_KV766195v1_fix"
# [513] "chr11_KZ559108v1_fix"    "chr11_KZ559109v1_fix"
# [515] "chr11_ML143356v1_fix"    "chr11_ML143357v1_fix"
# [517] "chr11_ML143358v1_fix"    "chr11_ML143359v1_fix"
# [519] "chr11_ML143360v1_fix"    "chr12_KN196482v1_fix"
# [521] "chr12_KN538369v1_fix"    "chr12_KN538370v1_fix"
# [523] "chr12_KQ759760v1_fix"    "chr12_KZ208916v1_fix"
# [525] "chr12_KZ208917v1_fix"    "chr12_ML143361v1_fix"
# [527] "chr12_ML143362v1_fix"    "chr13_KN196483v1_fix"
# [529] "chr13_KN538371v1_fix"    "chr13_KN538372v1_fix"
# [531] "chr13_KN538373v1_fix"    "chr13_ML143363v1_fix"
# [533] "chr13_ML143364v1_fix"    "chr13_ML143365v1_fix"
# [535] "chr13_ML143366v1_fix"    "chr14_KZ208920v1_fix"
# [537] "chr14_ML143367v1_fix"    "chr15_KN538374v1_fix"
# [539] "chr15_ML143369v1_fix"    "chr15_ML143370v1_fix"
# [541] "chr15_ML143371v1_fix"    "chr15_ML143372v1_fix"
# [543] "chr16_KV880768v1_fix"    "chr16_KZ559113v1_fix"
# [545] "chr16_ML143373v1_fix"    "chr17_KV575245v1_fix"
# [547] "chr17_KV766196v1_fix"    "chr17_ML143374v1_fix"
# [549] "chr17_ML143375v1_fix"    "chr18_KQ090028v1_fix"
# [551] "chr18_KZ208922v1_fix"    "chr18_KZ559115v1_fix"
# [553] "chr19_KN196484v1_fix"    "chr19_KQ458386v1_fix"
# [555] "chr19_ML143376v1_fix"    "chr21_ML143377v1_fix"
# [557] "chr22_KQ759762v1_fix"    "chr22_ML143378v1_fix"
# [559] "chr22_ML143379v1_fix"    "chr22_ML143380v1_fix"
# [561] "chrX_ML143381v1_fix"     "chrX_ML143382v1_fix"
# [563] "chrX_ML143383v1_fix"     "chrX_ML143384v1_fix"
# [565] "chrX_ML143385v1_fix"     "chrY_KN196487v1_fix"
# [567] "chrY_KZ208923v1_fix"     "chrY_KZ208924v1_fix"
# [569] "chr1_KQ458382v1_alt"     "chr1_KQ458383v1_alt"
# [571] "chr1_KQ458384v1_alt"     "chr1_KQ983255v1_alt"
# [573] "chr1_KV880763v1_alt"     "chr1_KZ208904v1_alt"
# [575] "chr1_KZ208905v1_alt"     "chr2_KQ983256v1_alt"
# [577] "chr2_KZ208907v1_alt"     "chr2_KZ208908v1_alt"
# [579] "chr3_KZ208909v1_alt"     "chr3_KZ559101v1_alt"
# [581] "chr3_KZ559102v1_alt"     "chr3_KZ559103v1_alt"
# [583] "chr3_KZ559105v1_alt"     "chr3_ML143343v1_alt"
# [585] "chr4_KQ090013v1_alt"     "chr4_KQ090014v1_alt"
# [587] "chr4_KQ090015v1_alt"     "chr4_KQ983258v1_alt"
# [589] "chr4_KV766193v1_alt"     "chr5_KN196477v1_alt"
# [591] "chr5_KV575243v1_alt"     "chr5_KZ208910v1_alt"
# [593] "chr6_KQ090017v1_alt"     "chr7_KZ208913v1_alt"
# [595] "chr7_KZ559106v1_alt"     "chr8_KZ559107v1_alt"
# [597] "chr9_KQ090018v1_alt"     "chr9_KQ090019v1_alt"
# [599] "chr10_KQ090020v1_alt"    "chr11_KN538368v1_alt"
# [601] "chr11_KZ559110v1_alt"    "chr11_KZ559111v1_alt"
# [603] "chr12_KQ090023v1_alt"    "chr12_KZ208918v1_alt"
# [605] "chr12_KZ559112v1_alt"    "chr13_KQ090024v1_alt"
# [607] "chr13_KQ090025v1_alt"    "chr14_KZ208919v1_alt"
# [609] "chr14_ML143368v1_alt"    "chr15_KQ031389v1_alt"
# [611] "chr16_KQ031390v1_alt"    "chr16_KQ090026v1_alt"
# [613] "chr16_KQ090027v1_alt"    "chr16_KZ208921v1_alt"
# [615] "chr17_KV766197v1_alt"    "chr17_KV766198v1_alt"
# [617] "chr17_KZ559114v1_alt"    "chr18_KQ458385v1_alt"
# [619] "chr18_KZ559116v1_alt"    "chr19_KV575246v1_alt"
# [621] "chr19_KV575247v1_alt"    "chr19_KV575248v1_alt"
# [623] "chr19_KV575249v1_alt"    "chr19_KV575250v1_alt"
# [625] "chr19_KV575251v1_alt"    "chr19_KV575252v1_alt"
# [627] "chr19_KV575253v1_alt"    "chr19_KV575254v1_alt"
# [629] "chr19_KV575255v1_alt"    "chr19_KV575256v1_alt"
# [631] "chr19_KV575257v1_alt"    "chr19_KV575258v1_alt"
# [633] "chr19_KV575259v1_alt"    "chr19_KV575260v1_alt"
# [635] "chr22_KN196485v1_alt"    "chr22_KN196486v1_alt"
# [637] "chr22_KQ458387v1_alt"    "chr22_KQ458388v1_alt"
# [639] "chr22_KQ759761v1_alt"    "chrX_KV766199v1_alt"

# %% [markdown]
# Chromosome sequence

# %%
chr2 <- genome$chr2

# %% [markdown]
# Read annotations for a group of genes
#
# These are a subset of the full genome annotations in the [GENCODE](https://www.gencodegenes.org/) project.

# %%
annotations <- import.gff3("data/tumor_suppressors.gff3") %>%
  print()
# Out:
# GRanges object with 1683 ranges and 23 metadata columns:
#          seqnames            ranges strand |   source        type     score
#             <Rle>         <IRanges>  <Rle> | <factor>    <factor> <numeric>
#      [1]    chr10 87863113-87971930      + |   HAVANA gene               NA
#      [2]    chr10 87863113-87971930      + |   HAVANA transcript         NA
#      [3]    chr10 87863113-87864548      + |   HAVANA exon               NA
#      [4]    chr10 87864470-87864548      + |   HAVANA CDS                NA
#      [5]    chr10 87864470-87864472      + |   HAVANA start_codon        NA
#      ...      ...               ...    ... .      ...         ...       ...
#   [1679]    chr17 43124026-43124115      - |   HAVANA exon               NA
#   [1680]    chr17 43124026-43124096      - |   HAVANA CDS                NA
#   [1681]    chr17 43124094-43124096      - |   HAVANA start_codon        NA
#   [1682]    chr17 43124737-43125364      - |   HAVANA UTR                NA
#   [1683]    chr17 43124097-43124115      - |   HAVANA UTR                NA
#              phase                     ID            gene_id      gene_type
#          <integer>            <character>        <character>    <character>
#      [1]      <NA>      ENSG00000171862.9  ENSG00000171862.9 protein_coding
#      [2]      <NA>      ENST00000371953.7  ENSG00000171862.9 protein_coding
#      [3]      <NA> exon:ENST00000371953..  ENSG00000171862.9 protein_coding
#      [4]         0 CDS:ENST00000371953...  ENSG00000171862.9 protein_coding
#      [5]         0 start_codon:ENST0000..  ENSG00000171862.9 protein_coding
#      ...       ...                    ...                ...            ...
#   [1679]      <NA> exon:ENST00000618469.. ENSG00000012048.20 protein_coding
#   [1680]         0 CDS:ENST00000618469... ENSG00000012048.20 protein_coding
#   [1681]         0 start_codon:ENST0000.. ENSG00000012048.20 protein_coding
#   [1682]      <NA> UTR5:ENST00000618469.. ENSG00000012048.20 protein_coding
#   [1683]      <NA> UTR5:ENST00000618469.. ENSG00000012048.20 protein_coding
#          gene_status   gene_name       level           havana_gene
#          <character> <character> <character>           <character>
#      [1]       KNOWN        PTEN           2  OTTHUMG00000018688.2
#      [2]       KNOWN        PTEN           2  OTTHUMG00000018688.2
#      [3]       KNOWN        PTEN           2  OTTHUMG00000018688.2
#      [4]       KNOWN        PTEN           2  OTTHUMG00000018688.2
#      [5]       KNOWN        PTEN           2  OTTHUMG00000018688.2
#      ...         ...         ...         ...                   ...
#   [1679]       KNOWN       BRCA1           2 OTTHUMG00000157426.10
#   [1680]       KNOWN       BRCA1           2 OTTHUMG00000157426.10
#   [1681]       KNOWN       BRCA1           2 OTTHUMG00000157426.10
#   [1682]       KNOWN       BRCA1           2 OTTHUMG00000157426.10
#   [1683]       KNOWN       BRCA1           2 OTTHUMG00000157426.10
#                     Parent     transcript_id transcript_type transcript_status
#            <CharacterList>       <character>     <character>       <character>
#      [1]                                <NA>            <NA>              <NA>
#      [2] ENSG00000171862.9 ENST00000371953.7  protein_coding             KNOWN
#      [3] ENST00000371953.7 ENST00000371953.7  protein_coding             KNOWN
#      [4] ENST00000371953.7 ENST00000371953.7  protein_coding             KNOWN
#      [5] ENST00000371953.7 ENST00000371953.7  protein_coding             KNOWN
#      ...               ...               ...             ...               ...
#   [1679] ENST00000618469.1 ENST00000618469.1  protein_coding             KNOWN
#   [1680] ENST00000618469.1 ENST00000618469.1  protein_coding             KNOWN
#   [1681] ENST00000618469.1 ENST00000618469.1  protein_coding             KNOWN
#   [1682] ENST00000618469.1 ENST00000618469.1  protein_coding             KNOWN
#   [1683] ENST00000618469.1 ENST00000618469.1  protein_coding             KNOWN
#          transcript_name transcript_support_level
#              <character>              <character>
#      [1]            <NA>                     <NA>
#      [2]        PTEN-001                        1
#      [3]        PTEN-001                        1
#      [4]        PTEN-001                        1
#      [5]        PTEN-001                        1
#      ...             ...                      ...
#   [1679]       BRCA1-027                        1
#   [1680]       BRCA1-027                        1
#   [1681]       BRCA1-027                        1
#   [1682]       BRCA1-027                        1
#   [1683]       BRCA1-027                        1
#                                               tag    havana_transcript
#                                   <CharacterList>          <character>
#      [1]                                                          <NA>
#      [2]            basic,appris_principal_1,CCDS OTTHUMT00000049241.1
#      [3]            basic,appris_principal_1,CCDS OTTHUMT00000049241.1
#      [4]            basic,appris_principal_1,CCDS OTTHUMT00000049241.1
#      [5]            basic,appris_principal_1,CCDS OTTHUMT00000049241.1
#      ...                                      ...                  ...
#   [1679] alternative_5_UTR,mRNA_end_NF,cds_end_NF OTTHUMT00000475526.2
#   [1680] alternative_5_UTR,mRNA_end_NF,cds_end_NF OTTHUMT00000475526.2
#   [1681] alternative_5_UTR,mRNA_end_NF,cds_end_NF OTTHUMT00000475526.2
#   [1682] alternative_5_UTR,mRNA_end_NF,cds_end_NF OTTHUMT00000475526.2
#   [1683] alternative_5_UTR,mRNA_end_NF,cds_end_NF OTTHUMT00000475526.2
#                 protein_id      ccdsid exon_number           exon_id
#                <character> <character> <character>       <character>
#      [1]              <NA>        <NA>        <NA>              <NA>
#      [2] ENSP00000361021.3 CCDS31238.1        <NA>              <NA>
#      [3] ENSP00000361021.3 CCDS31238.1           1 ENSE00001456562.3
#      [4] ENSP00000361021.3 CCDS31238.1           1 ENSE00001456562.3
#      [5] ENSP00000361021.3 CCDS31238.1           1 ENSE00001456562.3
#      ...               ...         ...         ...               ...
#   [1679] ENSP00000478114.1        <NA>           2 ENSE00003726859.1
#   [1680] ENSP00000478114.1        <NA>           2 ENSE00003726859.1
#   [1681] ENSP00000478114.1        <NA>           2 ENSE00003726859.1
#   [1682] ENSP00000478114.1        <NA>           1 ENSE00003753509.1
#   [1683] ENSP00000478114.1        <NA>           2 ENSE00003726859.1
#   -------
#   seqinfo: 3 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# We can convert from `GRanges` to  `tibble` and vice versa.

# %%
annotations %>%
  as_tibble() %>%
  # distinct(type) %>%
  distinct(gene_name) %>%
  # GRanges()
  print()
# Out:
# # A tibble: 5 × 1
#   gene_name
#   <chr>
# 1 PTEN
# 2 BRCA2
# 3 RB1
# 4 TP53
# 5 BRCA1

# %% [markdown]
# Group exons into transcripts
#
# We use `split` function with `$` to refer to columns.
#
# Each group is list of `GRanges` or a `GRangesList` object.

# %%
transcripts <- annotations %>%
  filter(type == "exon") %>%
  split(.$transcript_id) 
  # as_tibble() 

transcripts
# Out:
# GRangesList object of length 78:
# $ENST00000267163.4
# GRanges object with 27 ranges and 23 metadata columns:
#        seqnames            ranges strand |   source     type     score
#           <Rle>         <IRanges>  <Rle> | <factor> <factor> <numeric>
#    [1]    chr13 48303775-48304049      + |   HAVANA     exon        NA
#    [2]    chr13 48307280-48307406      + |   HAVANA     exon        NA
#    [3]    chr13 48342599-48342714      + |   HAVANA     exon        NA
#    [4]    chr13 48345080-48345199      + |   HAVANA     exon        NA
#    [5]    chr13 48347825-48347863      + |   HAVANA     exon        NA
#    ...      ...               ...    ... .      ...      ...       ...
#   [23]    chr13 48465205-48465368      + |   HAVANA     exon        NA
#   [24]    chr13 48473360-48473390      + |   HAVANA     exon        NA
#   [25]    chr13 48476701-48476843      + |   HAVANA     exon        NA
#   [26]    chr13 48477355-48477404      + |   HAVANA     exon        NA
#   [27]    chr13 48479998-48481986      + |   HAVANA     exon        NA
#            phase                     ID            gene_id      gene_type
#        <integer>            <character>        <character>    <character>
#    [1]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#    [2]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#    [3]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#    [4]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#    [5]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#    ...       ...                    ...                ...            ...
#   [23]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#   [24]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#   [25]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#   [26]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#   [27]      <NA> exon:ENST00000267163.. ENSG00000139687.13 protein_coding
#        gene_status   gene_name       level          havana_gene
#        <character> <character> <character>          <character>
#    [1]       KNOWN         RB1           1 OTTHUMG00000016900.4
#    [2]       KNOWN         RB1           1 OTTHUMG00000016900.4
#    [3]       KNOWN         RB1           1 OTTHUMG00000016900.4
#    [4]       KNOWN         RB1           1 OTTHUMG00000016900.4
#    [5]       KNOWN         RB1           1 OTTHUMG00000016900.4
#    ...         ...         ...         ...                  ...
#   [23]       KNOWN         RB1           1 OTTHUMG00000016900.4
#   [24]       KNOWN         RB1           1 OTTHUMG00000016900.4
#   [25]       KNOWN         RB1           1 OTTHUMG00000016900.4
#   [26]       KNOWN         RB1           1 OTTHUMG00000016900.4
#   [27]       KNOWN         RB1           1 OTTHUMG00000016900.4
#                   Parent     transcript_id transcript_type transcript_status
#          <CharacterList>       <character>     <character>       <character>
#    [1] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#    [2] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#    [3] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#    [4] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#    [5] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#    ...               ...               ...             ...               ...
#   [23] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#   [24] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#   [25] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#   [26] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#   [27] ENST00000267163.4 ENST00000267163.4  protein_coding             KNOWN
#        transcript_name transcript_support_level
#            <character>              <character>
#    [1]         RB1-002                        1
#    [2]         RB1-002                        1
#    [3]         RB1-002                        1
#    [4]         RB1-002                        1
#    [5]         RB1-002                        1
#    ...             ...                      ...
#   [23]         RB1-002                        1
#   [24]         RB1-002                        1
#   [25]         RB1-002                        1
#   [26]         RB1-002                        1
#   [27]         RB1-002                        1
#                                          tag    havana_transcript
#                              <CharacterList>          <character>
#    [1] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#    [2] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#    [3] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#    [4] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#    [5] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#    ...                                   ...                  ...
#   [23] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#   [24] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#   [25] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#   [26] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#   [27] basic,appris_principal_1,exp_conf,... OTTHUMT00000044884.1
#               protein_id      ccdsid exon_number           exon_id
#              <character> <character> <character>       <character>
#    [1] ENSP00000267163.4 CCDS31973.1           1 ENSE00002199946.1
#    [2] ENSP00000267163.4 CCDS31973.1           2 ENSE00003469272.1
#    [3] ENSP00000267163.4 CCDS31973.1           3 ENSE00003588059.1
#    [4] ENSP00000267163.4 CCDS31973.1           4 ENSE00003494338.1
#    [5] ENSP00000267163.4 CCDS31973.1           5 ENSE00003621237.1
#    ...               ...         ...         ...               ...
#   [23] ENSP00000267163.4 CCDS31973.1          23 ENSE00000939685.1
#   [24] ENSP00000267163.4 CCDS31973.1          24 ENSE00001003962.1
#   [25] ENSP00000267163.4 CCDS31973.1          25 ENSE00003541600.1
#   [26] ENSP00000267163.4 CCDS31973.1          26 ENSE00003641827.1
#   [27] ENSP00000267163.4 CCDS31973.1          27 ENSE00001241067.7
#   -------
#   seqinfo: 3 sequences from an unspecified genome; no seqlengths
#
# ...
# <77 more elements>

# %% [markdown]
# Visualize transcript models for *TP53* gene

# %%
options(repr.plot.width = 15, repr.plot.height = 10)
annotations %>%
  filter(type == "exon") %>%
  filter(gene_name == "TP53") %>%
  split(.$transcript_id) %>%
  ggbio::autoplot() +
  theme_minimal()
# Out:
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
#
# Constructing graphics...
# plot without title

# %% [markdown]
# ## How do we extract transcript sequences?

# %%
GenomicFeatures::extractTranscriptSeqs(genome, transcripts)
# Out:
# DNAStringSet object of length 78:
#      width seq                                              names
#  [1]  4840 TCCGGTTTTTCTCAGGGGACGTT...TAACTCTCCTAGTATCTCATCC ENST00000267163.4
#  [2]  2579 GTTTTCCCCTCCCATGTGCTCAA...CCACCTGTGTGTCTGAGGGGTG ENST00000269305.8
#  [3]  3668 GAGCTCGCTGAGACTTCCTGGAC...AACTTGGTAGCAAACACTTCCA ENST00000352993.7
#  [4]  4497 GGGCCCCTGCGCTCAGGAGGCCT...GTCCTGCCAATGAGAAGAAAAA ENST00000354071.7
#  [5]  7094 GAGCTCGCTGAGACTTCCTGGAC...AACTTGGTAGCAAACACTTCCA ENST00000357654.7
#  ...   ... ...
# [74]  2579 GTTTTCCCCTCCCATGTGCTCAA...CCACCTGTGTGTCTGAGGGGTG ENST00000620739.4
# [75]   375 AAATAATTTCATGGGCATTAATT...ATAAAGAACCAGGAGTGGAAAG ENST00000621897.1
# [76]  2653 CTAGAGCCACCGTCCAGGGAGCA...TGCCACCTGTGTGTCTGAGGGG ENST00000622645.4
# [77]  2534 AAAGCGTGGGAATTACAGATAAA...TTGGGACATGAAGTTAACCACA ENST00000634433.1
# [78]  1883 TCTCAAAAGTCTAGAGCCACCGT...AAAATTAAACTTATATTTATTC ENST00000635293.1

# %% [markdown]
# # In-class exercises
#
# (20 minutes)

# %% [markdown]
# ### 1. Extract the coding sequence for all the transcripts in the annotation file above.
#
# The steps are identical to above except that you need to work with `CDS` features instead of `exon` features.
#
# If everything worked correctly, you should at least have the expected start and stop codons at the termini of each coding sequence.

# %%
GenomicFeatures::extractTranscriptSeqs(genome, transcripts) %>%

# %% [markdown]
# ### 2. Find the transcripts with the longest coding sequence for each gene
#
# **Steps**
#
# - Convert annotations to a `tibble`
# - Filter for `CDS` features
# - Group by gene name and transcript id
# - Sum the `width` column for each group
# - Group by gene name and filter for the transcript with the longest `width` column
